# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
def prepare_data(file_path):
    norm_genes = pd.read_csv(file_path, sep="\t")
    y_labels = norm_genes["Gene"].tolist()
    norm_genes = norm_genes.drop(columns=['Gene'])
    return norm_genes, y_labels

# %%
# metrics: cityblock, cosine
def plot_cluster_genes(dataframe, z_score, file_name, fig_title, y_labels):
    sns.set(font_scale=2.25)
    fig_size = (25,60)
    g = sns.clustermap(dataframe,
                   row_cluster=True,
                   col_cluster=False,
                   cmap="RdBu_r",
                   xticklabels='auto',
                   yticklabels=y_labels,
                   figsize=fig_size,
                   metric='cosine',
                   #z_score=z_score,
                   standard_scale=0
                  )
    g.fig.suptitle(fig_title)
    g.ax_heatmap.set_xlabel("Samples")
    g.ax_heatmap.set_ylabel("Genes")
    for a in g.ax_col_dendrogram.collections:
        a.set_linewidth(3)
    for a in g.ax_row_dendrogram.collections:
        a.set_linewidth(3)
    #g.savefig('{}.pdf'.format(file_name), dpi=300, figsize=fig_size)
    #g.savefig('{}.png'.format(file_name), dpi=300, figsize=fig_size)

# %%
path = "Normalized_counts_all_DEgenes_for_clustering.tabular"
normalised_counts_all_genes, y_labels = prepare_data(path)
plot_cluster_genes(normalised_counts_all_genes, 0, "heatmap_with_Seaborn_clustermap_python", 'DEgenes for clustering_n=131', y_labels)

# %%
#normalised_counts_all_genes_log = np.log(normalised_counts_all_genes + 1.0)
#plot_cluster_genes(normalised_counts_all_genes_log, None, "heatmap_with_Seaborn_clustermap_python_log")

# %%
path = "Normalized_counts_top100_DEgenes_for_clustering.tabular"
normalised_counts_all_genes, y_labels = prepare_data(path)
plot_cluster_genes(normalised_counts_all_genes, 0, "heatmap_with_Seaborn_clustermap_python", 'DEgenes for clustering_n=100', y_labels)

# %%
path = "Normalized_counts_top70_DEgenes_for_clustering.tabular"
normalised_counts_all_genes, y_labels = prepare_data(path)
plot_cluster_genes(normalised_counts_all_genes, 0, "heatmap_with_Seaborn_clustermap_python", 'DEgenes for clustering_n=70', y_labels)

# %%
path = "Normalized_counts_top50_DEgenes_for_clustering.tabular"
normalised_counts_all_genes, y_labels = prepare_data(path)
plot_cluster_genes(normalised_counts_all_genes, 0, "heatmap_with_Seaborn_clustermap_python", 'DEgenes for clustering_n=50', y_labels)

# %%
path = "Normalized_counts_top20_DEgenes_for_clustering.tabular"
normalised_counts_all_genes, y_labels = prepare_data(path)
plot_cluster_genes(normalised_counts_all_genes, 0, "heatmap_with_Seaborn_clustermap_python", 'DEgenes for clustering_n=20', y_labels)
